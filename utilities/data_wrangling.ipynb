# %%
import pandas as pd
df = pd.read_csv('data.csv')
print(df)
# Out:
#            Date                Description   Amount Transaction Type  \
# 0    01/01/2018                     Amazon    11.11            debit
# 1    01/02/2018           Mortgage Payment  1247.44            debit
# 2    01/02/2018            Thai Restaurant    24.22            debit
# 3    01/03/2018        Credit Card Payment  2298.09           credit
# 4    01/04/2018                    Netflix    11.76            debit
# ..          ...                        ...      ...              ...
# 801  09/27/2019          Biweekly Paycheck  2250.00           credit
# 802  09/28/2019                         BP    33.46            debit
# 803  09/28/2019                     Sheetz     4.27            debit
# 804  09/30/2019                  Starbucks     1.75            debit
# 805  09/30/2019  Internet Service Provider    75.00            debit
#
#                 Category   Account Name
# 0               Shopping  Platinum Card
# 1        Mortgage & Rent       Checking
# ...

# %%
df.head()
# Out:
#          Date          Description   Amount Transaction Type  \
# 0  01/01/2018               Amazon    11.11            debit
# 1  01/02/2018     Mortgage Payment  1247.44            debit
# 2  01/02/2018      Thai Restaurant    24.22            debit
# 3  01/03/2018  Credit Card Payment  2298.09           credit
# 4  01/04/2018              Netflix    11.76            debit
#
#               Category   Account Name
# 0             Shopping  Platinum Card
# 1      Mortgage & Rent       Checking
# 2          Restaurants    Silver Card
# 3  Credit Card Payment  Platinum Card
# 4        Movies & DVDs  Platinum Card

# %%
category = df['Category'].unique()
category
# Out:
# array(['Shopping', 'Mortgage & Rent', 'Restaurants',
#        'Credit Card Payment', 'Movies & DVDs', 'Home Improvement',
#        'Utilities', 'Music', 'Mobile Phone', 'Gas & Fuel', 'Groceries',
#        'Paycheck', 'Fast Food', 'Coffee Shops', 'Internet', 'Haircut',
#        'Alcohol & Bars', 'Auto Insurance', 'Entertainment',
#        'Food & Dining', 'Television', 'Electronics & Software'],
#       dtype=object)

# %%
df.loc[df['Transaction Type'] == 'debit']['Category'].unique()
# inc
# Out:
# array(['Shopping', 'Mortgage & Rent', 'Restaurants', 'Movies & DVDs',
#        'Home Improvement', 'Utilities', 'Music', 'Mobile Phone',
#        'Gas & Fuel', 'Groceries', 'Fast Food', 'Credit Card Payment',
#        'Coffee Shops', 'Internet', 'Haircut', 'Alcohol & Bars',
#        'Auto Insurance', 'Entertainment', 'Food & Dining', 'Television',
#        'Electronics & Software'], dtype=object)

# %% [markdown]
# ## replacing transaction types

# %%
df = df.replace('Credit Card Payment', 'Investments')
df
# Out:
#            Date                Description   Amount Transaction Type  \
# 0    01/01/2018                     Amazon    11.11            debit
# 1    01/02/2018           Mortgage Payment  1247.44            debit
# 2    01/02/2018            Thai Restaurant    24.22            debit
# 3    01/03/2018                Investments  2298.09           credit
# 4    01/04/2018                    Netflix    11.76            debit
# ..          ...                        ...      ...              ...
# 801  09/27/2019          Biweekly Paycheck  2250.00           credit
# 802  09/28/2019                         BP    33.46            debit
# 803  09/28/2019                     Sheetz     4.27            debit
# 804  09/30/2019                  Starbucks     1.75            debit
# 805  09/30/2019  Internet Service Provider    75.00            debit
#
#             Category   Account Name
# 0           Shopping  Platinum Card
# 1    Mortgage & Rent       Checking
# ...

# %%
df.loc[df['Transaction Type' ] == 'debit']
# Out:
#            Date                Description   Amount Transaction Type  \
# 0    01/01/2018                     Amazon    11.11            debit
# 1    01/02/2018           Mortgage Payment  1247.44            debit
# 2    01/02/2018            Thai Restaurant    24.22            debit
# 4    01/04/2018                    Netflix    11.76            debit
# 5    01/05/2018            American Tavern    25.85            debit
# ..          ...                        ...      ...              ...
# 800  09/23/2019                     Amazon    24.63            debit
# 802  09/28/2019                         BP    33.46            debit
# 803  09/28/2019                     Sheetz     4.27            debit
# 804  09/30/2019                  Starbucks     1.75            debit
# 805  09/30/2019  Internet Service Provider    75.00            debit
#
#             Category   Account Name
# 0           Shopping  Platinum Card
# 1    Mortgage & Rent       Checking
# ...

# %%
df = df.replace('credit', 'income')
df = df.replace('debit', 'expense')
df = df.drop('Description', axis=1)
df
# Out:
#            Date   Amount Transaction Type         Category   Account Name
# 0    01/01/2018    11.11          expense         Shopping  Platinum Card
# 1    01/02/2018  1247.44          expense  Mortgage & Rent       Checking
# 2    01/02/2018    24.22          expense      Restaurants    Silver Card
# 3    01/03/2018  2298.09           income      Investments  Platinum Card
# 4    01/04/2018    11.76          expense    Movies & DVDs  Platinum Card
# ..          ...      ...              ...              ...            ...
# 801  09/27/2019  2250.00           income         Paycheck       Checking
# 802  09/28/2019    33.46          expense       Gas & Fuel  Platinum Card
# 803  09/28/2019     4.27          expense       Gas & Fuel  Platinum Card
# 804  09/30/2019     1.75          expense     Coffee Shops  Platinum Card
# 805  09/30/2019    75.00          expense         Internet       Checking
#
# [806 rows x 5 columns]

# %% [markdown]
# ## changing date format

# %%
df['Date'] = pd.to_datetime(df['Date'])
df
# Out:
#           Date   Amount Transaction Type         Category   Account Name
# 0   2018-01-01    11.11          expense         Shopping  Platinum Card
# 1   2018-01-02  1247.44          expense  Mortgage & Rent       Checking
# 2   2018-01-02    24.22          expense      Restaurants    Silver Card
# 3   2018-01-03  2298.09           income      Investments  Platinum Card
# 4   2018-01-04    11.76          expense    Movies & DVDs  Platinum Card
# ..         ...      ...              ...              ...            ...
# 801 2019-09-27  2250.00           income         Paycheck       Checking
# 802 2019-09-28    33.46          expense       Gas & Fuel  Platinum Card
# 803 2019-09-28     4.27          expense       Gas & Fuel  Platinum Card
# 804 2019-09-30     1.75          expense     Coffee Shops  Platinum Card
# 805 2019-09-30    75.00          expense         Internet       Checking
#
# [806 rows x 5 columns]

# %%
df['Account Name'].unique()
# Out:
# array(['Platinum Card', 'Checking', 'Silver Card'], dtype=object)

# %% [markdown]
# ## creating sender_id and receiver_id columns

# %%
import uuid
import random

rec_id = []

for x in range(806):
    id = uuid.uuid4()
    rec_id.append(str(id)[9:18])

rec_id
# Out:
# ['e8e8-44bc',
#  'f8e8-4956',
#  '03c7-48d2',
#  '5c10-40fd',
#  '0538-4712',
#  '3e18-4a88',
#  '117c-43a0',
#  '04ae-4ef4',
#  'e6c9-4e94',
#  'd990-4000',
#  'af88-4415',
#  'c876-4a9f',
#  'c3fe-4c37',
#  'def8-4d8b',
#  '71b8-4f10',
#  'e742-42cc',
#  'b172-4ede',
#  '847c-451f',
#  'cd78-4b75',
#  '6b4b-4001',
#  '3f68-4ca4',
#  '0917-4446',
#  '1bd9-488b',
#  'f8d4-4640',
#  '16ba-4a30',
#  'c62e-4164',
#  '10dc-49a1',
#  '34b7-4706',
#  '4d83-4f48',
#  '177a-4fb0',
#  'eeca-4931',
#  'd390-49e7',
#  'ce92-4ec8',
#  '883f-4c39',
#  '7c0c-43a2',
#  '2b40-44c7',
#  'de05-4568',
#  '608d-4a45',
#  'eed9-4865',
#  '452c-43a9',
#  'a2df-462c',
#  '8e53-41c0',
#  'edac-4219',
#  'fd75-4cb9',
#  'f6db-4050',
#  'e39b-4dee',
#  '1bb5-4236',
#  '53a5-4264',
#  'e1e7-4100',
#  '5b9e-4916',
#  'a07f-4b19',
#  '80c5-4dab',
#  'd02d-4114',
#  '9b5a-4ef8',
#  'f354-4d32',
#  '5ea5-48d8',
#  'd5e3-433d',
#  '1a29-4235',
#  '42f2-4fe2',
#  '69a1-4a45',
#  'ca1c-4bba',
#  '6332-451b',
# ...

# %%
#df.insert(1, "receiver_id", rec_id)
df.insert(1, "sender_id", 'abc123')
# df = df.drop('sender_id', axis=1)

# %%
df.tail()
# Out:
#           Date sender_id   Amount Transaction Type      Category  \
# 801 2019-09-27    abc123  2250.00           income      Paycheck
# 802 2019-09-28    abc123    33.46          expense    Gas & Fuel
# 803 2019-09-28    abc123     4.27          expense    Gas & Fuel
# 804 2019-09-30    abc123     1.75          expense  Coffee Shops
# 805 2019-09-30    abc123    75.00          expense      Internet
#
#       Account Name
# 801       Checking
# 802  Platinum Card
# 803  Platinum Card
# 804  Platinum Card
# 805       Checking

# %% [markdown]
# ## changing date of transactions

# %%
df['Date'] = df['Date'] + pd.Timedelta(days=1235)
df
# Out:
#           Date sender_id   Amount Transaction Type         Category  \
# 0   2021-05-20    abc123    11.11          expense         Shopping
# 1   2021-05-21    abc123  1247.44          expense  Mortgage & Rent
# 2   2021-05-21    abc123    24.22          expense      Restaurants
# 3   2021-05-22    abc123  2298.09           income      Investments
# 4   2021-05-23    abc123    11.76          expense    Movies & DVDs
# ..         ...       ...      ...              ...              ...
# 801 2023-02-13    abc123  2250.00           income         Paycheck
# 802 2023-02-14    abc123    33.46          expense       Gas & Fuel
# 803 2023-02-14    abc123     4.27          expense       Gas & Fuel
# 804 2023-02-16    abc123     1.75          expense     Coffee Shops
# 805 2023-02-16    abc123    75.00          expense         Internet
#
#       Account Name
# 0    Platinum Card
# 1         Checking
# 2      Silver Card
# 3    Platinum Card
# 4    Platinum Card
# ..             ...
# ...

# %% [markdown]
# ## transaction id

# %%
import uuid
import random

t_id = []

for x in range(806):
    id = uuid.uuid4()
    t_id.append(str(id)[0:8])

t_id
# Out:
# ['37bfb35c',
#  '04d83407',
#  'fda5e368',
#  'dfa69094',
#  'a381db26',
#  '00b0b6e2',
#  'b4fa5038',
#  '39c27981',
#  'e183ef1a',
#  '7c9b2b26',
#  '2ba7521e',
#  '7dc0db78',
#  'cfafa121',
#  'ef832a90',
#  'bea35c1a',
#  '93684a5b',
#  '675038f8',
#  '7fa1f33e',
#  '39876b39',
#  'fe0af2dc',
#  'e339fd72',
#  'e78074dc',
#  '97e27457',
#  '9767e2cd',
#  'e64ddeb4',
#  'a7ffa4a7',
#  '04ff541a',
#  '956b1cd8',
#  'fac1c8bd',
#  'e01f03a2',
#  '04dcfca1',
#  'a344a725',
#  'ef9c7e4c',
#  '5712af48',
#  '28eae246',
#  '48f9067c',
#  '5223408b',
#  '7a4aa38b',
#  '305667b3',
#  'aad15504',
#  'e4592848',
#  'b618cfec',
#  '4c972187',
#  'd7e9007f',
#  '1b0e8dc2',
#  '172afa8d',
#  '59ee11e1',
#  '5c2c46d6',
#  '7c38b5a6',
#  '74cb66e0',
#  '7fc44151',
#  '869e81a3',
#  '9ad85075',
#  '42c2e105',
#  '0dc58183',
#  'efde3a62',
#  'e2fcc9f5',
#  '57e0007e',
#  'b6d25330',
#  '3feb6791',
#  'ea700c94',
#  'ac7f6147',
#  '04d5f3c8',
#  '415c215a',
#  '84e2a0c1',
#  'b8e4e708',
# ...

# %%
df.insert(0, 'transaction_id', t_id)
df
# Out:
#     transaction_id       Date sender_id   Amount Transaction Type  \
# 0         37bfb35c 2021-05-20    abc123    11.11          expense
# 1         04d83407 2021-05-21    abc123  1247.44          expense
# 2         fda5e368 2021-05-21    abc123    24.22          expense
# 3         dfa69094 2021-05-22    abc123  2298.09           income
# 4         a381db26 2021-05-23    abc123    11.76          expense
# ..             ...        ...       ...      ...              ...
# 801       e58ffd24 2023-02-13    abc123  2250.00           income
# 802       5d0a55ab 2023-02-14    abc123    33.46          expense
# 803       649773cb 2023-02-14    abc123     4.27          expense
# 804       5afbbc78 2023-02-16    abc123     1.75          expense
# 805       15978ee0 2023-02-16    abc123    75.00          expense
#
#             Category   Account Name
# 0           Shopping  Platinum Card
# 1    Mortgage & Rent       Checking
# 2        Restaurants    Silver Card
# ...

# %%
df.insert(3, 'receiver_id', rec_id)
df
# Out:
#     transaction_id       Date sender_id receiver_id   Amount Transaction Type  \
# 0         37bfb35c 2021-05-20    abc123   e8e8-44bc    11.11          expense
# 1         04d83407 2021-05-21    abc123   f8e8-4956  1247.44          expense
# 2         fda5e368 2021-05-21    abc123   03c7-48d2    24.22          expense
# 3         dfa69094 2021-05-22    abc123   5c10-40fd  2298.09           income
# 4         a381db26 2021-05-23    abc123   0538-4712    11.76          expense
# ..             ...        ...       ...         ...      ...              ...
# 801       e58ffd24 2023-02-13    abc123   dcf6-42dc  2250.00           income
# 802       5d0a55ab 2023-02-14    abc123   ebbc-411a    33.46          expense
# 803       649773cb 2023-02-14    abc123   e4a9-436c     4.27          expense
# 804       5afbbc78 2023-02-16    abc123   50f7-47ea     1.75          expense
# 805       15978ee0 2023-02-16    abc123   73b8-4f97    75.00          expense
#
# ...

# %%
df = df.drop('Account Name', axis=1)
df
# Out:
#     transaction_id       Date sender_id receiver_id   Amount Transaction Type  \
# 0         37bfb35c 2021-05-20    abc123   e8e8-44bc    11.11          expense
# 1         04d83407 2021-05-21    abc123   f8e8-4956  1247.44          expense
# 2         fda5e368 2021-05-21    abc123   03c7-48d2    24.22          expense
# 3         dfa69094 2021-05-22    abc123   5c10-40fd  2298.09           income
# 4         a381db26 2021-05-23    abc123   0538-4712    11.76          expense
# ..             ...        ...       ...         ...      ...              ...
# 801       e58ffd24 2023-02-13    abc123   dcf6-42dc  2250.00           income
# 802       5d0a55ab 2023-02-14    abc123   ebbc-411a    33.46          expense
# 803       649773cb 2023-02-14    abc123   e4a9-436c     4.27          expense
# 804       5afbbc78 2023-02-16    abc123   50f7-47ea     1.75          expense
# 805       15978ee0 2023-02-16    abc123   73b8-4f97    75.00          expense
#
#             Category
# ...

# %%
exp = df.loc[df['Transaction Type'] == 'expense']['Category'].unique()
exp
# Out:
# array(['Shopping', 'Mortgage & Rent', 'Restaurants', 'Movies & DVDs',
#        'Home Improvement', 'Utilities', 'Music', 'Mobile Phone',
#        'Gas & Fuel', 'Groceries', 'Fast Food', 'Investments',
#        'Coffee Shops', 'Internet', 'Haircut', 'Alcohol & Bars',
#        'Auto Insurance', 'Entertainment', 'Food & Dining', 'Television',
#        'Electronics & Software'], dtype=object)

# %%
df.loc[(df['Transaction Type'] == 'expense') & (df['Category'] == 'Investments')]
# Out:
#     transaction_id       Date sender_id receiver_id   Amount Transaction Type  \
# 24        e64ddeb4 2021-06-10    abc123   16ba-4a30   554.99          expense
# 26        04ff541a 2021-06-11    abc123   10dc-49a1   309.81          expense
# 40        e4592848 2021-06-26    abc123   a2df-462c   154.13          expense
# 60        ea700c94 2021-07-15    abc123   ca1c-4bba   765.37          expense
# 64        84e2a0c1 2021-07-16    abc123   731c-4718   156.11          expense
# ..             ...        ...       ...         ...      ...              ...
# 772       55f11f20 2023-01-23    abc123   76f7-4176   502.75          expense
# 782       06c12a78 2023-01-29    abc123   5b29-45f3   360.56          expense
# 787       17efe7fb 2023-02-02    abc123   2a2a-43ed    90.57          expense
# 793       dc3ef832 2023-02-04    abc123   f330-4c8e  1606.46          expense
# 798       ffc24dd2 2023-02-09    abc123   88dd-487d     9.43          expense
#
#         Category
# ...

# %%
inc = df.loc[df['Transaction Type'] == 'income']['Category'].unique()
inc
# Out:
# array(['Investments', 'Paycheck'], dtype=object)

# %% [markdown]
# ## changing expense investments

# %%
import numpy as np  

e = ['Shopping', 'Mortgage & Rent', 'Restaurants', 'Movies & DVDs',
       'Home Improvement', 'Utilities', 'Music', 'Mobile Phone',
       'Gas & Fuel', 'Groceries', 'Fast Food',
       'Coffee Shops', 'Internet', 'Haircut', 'Alcohol & Bars',
       'Auto Insurance', 'Entertainment', 'Food & Dining', 'Television',
       'Electronics & Software']

# temp = df.loc[(df['Transaction Type'] == 'expense') & (df['Category'] == 'Investments')]
# temp

# %%
np.random.seed(1)
m = df['Category'].eq('Investments') & df['Transaction Type'].eq('expense')
m.describe()
# Out:
# count       806
# unique        2
# top       False
# freq        735
# dtype: object

# %%
df.loc[m, 'Category'] = np.random.choice(e)

# %%
df.loc[(df['Transaction Type'] == 'expense') & (df['Category'] == 'Investments')]
# Out:
# Empty DataFrame
# Columns: [transaction_id, Date, sender_id, receiver_id, Amount, Transaction Type, Category]
# Index: []

# %%
h = df.loc[df['Category'] == 'Investments']['Transaction Type']
h.describe()
# Out:
# count         72
# unique         1
# top       income
# freq          72
# Name: Transaction Type, dtype: object

# %% [markdown]
# ## changing investment types

# %%
inv = ['Mutual Funds', 'Stocks']

np.random.seed(1) 
m = df['Category'].eq('Investments')
df.loc[m, 'Category'] = np.random.choice(inv, size=m.sum())

# %%
df
# Out:
#     transaction_id       Date sender_id receiver_id   Amount Transaction Type  \
# 0         37bfb35c 2021-05-20    abc123   e8e8-44bc    11.11          expense
# 1         04d83407 2021-05-21    abc123   f8e8-4956  1247.44          expense
# 2         fda5e368 2021-05-21    abc123   03c7-48d2    24.22          expense
# 3         dfa69094 2021-05-22    abc123   5c10-40fd  2298.09           income
# 4         a381db26 2021-05-23    abc123   0538-4712    11.76          expense
# ..             ...        ...       ...         ...      ...              ...
# 801       e58ffd24 2023-02-13    abc123   dcf6-42dc  2250.00           income
# 802       5d0a55ab 2023-02-14    abc123   ebbc-411a    33.46          expense
# 803       649773cb 2023-02-14    abc123   e4a9-436c     4.27          expense
# 804       5afbbc78 2023-02-16    abc123   50f7-47ea     1.75          expense
# 805       15978ee0 2023-02-16    abc123   73b8-4f97    75.00          expense
#
#             Category
# ...

# %%
df.loc[df['Category'] == 'Mutual Funds']
# Out:
#     transaction_id       Date sender_id receiver_id   Amount Transaction Type  \
# 23        9767e2cd 2021-06-10    abc123   f8d4-4640   309.81           income
# 38        305667b3 2021-06-24    abc123   eed9-4865   145.14           income
# 111       8cf34955 2021-08-19    abc123   fa73-4a95   817.14           income
# 117       08e600e6 2021-08-21    abc123   adb4-48ae   363.08           income
# 147       dea51d18 2021-09-12    abc123   35de-43cd  1216.94           income
# 185       c2d19d77 2021-10-07    abc123   4a36-4ce1   283.07           income
# 199       b70e6a18 2021-10-19    abc123   47ca-4259   235.18           income
# 215       c945cd38 2021-10-31    abc123   16c8-47c2   283.44           income
# 226       4d9810db 2021-11-06    abc123   cd05-40eb    89.45           income
# 232       13722cc7 2021-11-11    abc123   5ae1-4000   942.76           income
# 250       0c7509be 2021-11-25    abc123   47a3-4dbb   242.16           income
# ...

# %% [markdown]
# ## dropping expense transactions

# %%
df.loc[df['Transaction Type'] == 'income']['Amount'].sum()
# Out:
# 124269.76000000001

# %%
df.loc[df['Transaction Type'] == 'expense']['Amount'].sum()
# Out:
# 96083.78

# %%
len(df)
# Out:
# 806

# %%
del_row = df.loc[(df['Amount'] > 1000) & (df['Transaction Type'] == 'expense')]
len(del_row)
# Out:
# 29

# %%
thousand = del_row.sample(12)
thsum = thousand['Amount'].sum()
thsum
# Out:
# 29701.79

# %%
thousand.index
# Out:
# Int64Index([316, 752, 34, 172, 67, 204, 356, 618, 157, 793, 676, 515], dtype='int64')

# %%
th_index = [316, 752, 34, 172, 67, 204, 356, 618, 157, 793, 676, 515]

# %%
d_row = df.loc[(df['Amount'] < 1000) & (df['Amount'] > 500) & (df['Transaction Type'] == 'expense')]
d_row
# Out:
#     transaction_id       Date sender_id receiver_id  Amount Transaction Type  \
# 24        e64ddeb4 2021-06-10    abc123   16ba-4a30  554.99          expense
# 60        ea700c94 2021-07-15    abc123   ca1c-4bba  765.37          expense
# 75        c26a0542 2021-07-22    abc123   30b0-4b9c  761.59          expense
# 97        31097186 2021-08-09    abc123   8414-4bd3  559.91          expense
# 112       dc665029 2021-08-19    abc123   a320-4e4c  817.14          expense
# 149       367806ac 2021-09-13    abc123   148b-4847  769.72          expense
# 166       0111ac42 2021-09-25    abc123   6041-4da2  601.40          expense
# 233       47023da4 2021-11-11    abc123   d36f-4f46  942.76          expense
# 315       72cc2d3e 2022-01-21    abc123   f5b8-4b95  687.29          expense
# 429       cefdb2b8 2022-04-18    abc123   3703-4d19  582.99          expense
# 534       6d3ddb95 2022-07-08    abc123   5eb9-4628  574.84          expense
# ...

# %%
print(len(d_row))
five = d_row.sample(10)
fivesum = five['Amount'].sum()
print(fivesum)
# Out:
# 17
# 7368.53

# %%
five.index
# Out:
# Int64Index([149, 648, 534, 233, 112, 708, 75, 619, 604, 97], dtype='int64')

# %%
f_index = [149, 648, 534, 233, 112, 708, 75, 619, 604, 97]
del_index = f_index + th_index
del_index
# Out:
# [149,
#  648,
#  534,
#  233,
#  112,
#  708,
#  75,
#  619,
#  604,
#  97,
#  316,
#  752,
#  34,
#  172,
#  67,
#  204,
#  356,
#  618,
#  157,
#  793,
#  676,
#  515]

# %%
df.drop(del_index, axis=0, inplace=True)
df.loc[df['Transaction Type'] == 'expense']['Amount'].sum()
# Out:
# 59013.46

# %%
fivesum = five['Amount'].sum()
print(fivesum)
# Out:
# 7005.28

# %%
df
# Out:
#     transaction_id       Date sender_id receiver_id   Amount Transaction Type  \
# 0         37bfb35c 2021-05-20    abc123   e8e8-44bc    11.11          expense
# 1         04d83407 2021-05-21    abc123   f8e8-4956  1247.44          expense
# 2         fda5e368 2021-05-21    abc123   03c7-48d2    24.22          expense
# 3         dfa69094 2021-05-22    abc123   5c10-40fd  2298.09           income
# 4         a381db26 2021-05-23    abc123   0538-4712    11.76          expense
# ..             ...        ...       ...         ...      ...              ...
# 801       e58ffd24 2023-02-13    abc123   dcf6-42dc  2250.00           income
# 802       5d0a55ab 2023-02-14    abc123   ebbc-411a    33.46          expense
# 803       649773cb 2023-02-14    abc123   e4a9-436c     4.27          expense
# 804       5afbbc78 2023-02-16    abc123   50f7-47ea     1.75          expense
# 805       15978ee0 2023-02-16    abc123   73b8-4f97    75.00          expense
#
#             Category
# ...

# %% [markdown]
# ## replace paycheck with salary

# %%
df.replace('Paycheck', 'Salary', inplace=True)
df.loc[df['Category'] == 'Salary']
# Out:
#     transaction_id       Date sender_id receiver_id  Amount Transaction Type  \
# 13        ef832a90 2021-05-31    abc123   def8-4d8b  2000.0           income
# 20        e339fd72 2021-06-07    abc123   3f68-4ca4  2000.0           income
# 35        48f9067c 2021-06-21    abc123   2b40-44c7  2000.0           income
# 51        869e81a3 2021-07-05    abc123   80c5-4dab  2000.0           income
# 68        293d71b1 2021-07-19    abc123   3367-4e20  2000.0           income
# 89        0784b714 2021-08-02    abc123   3573-4bfa  2000.0           income
# 104       bb2c9ace 2021-08-16    abc123   7fe2-4b85  2000.0           income
# 130       27e3d2e2 2021-08-30    abc123   e44b-4918  2000.0           income
# 150       27947205 2021-09-13    abc123   06b0-4611  2000.0           income
# 171       5759c2de 2021-09-27    abc123   cf18-4a34  2000.0           income
# 191       a8427be9 2021-10-11    abc123   4895-4adf  2000.0           income
# ...

# %% [markdown]
# ## creating category ids

# %%
expense_cat = df.loc[df['Transaction Type'] == 'expense']['Category'].unique()
print(len(expense_cat))

expense_id = {}
for x in range(1, len(expense_cat)+1):
    expense_id[expense_cat[x-1]] = x

expense_id
# Out:
# 20
# {'Shopping': 1,
#  'Mortgage & Rent': 2,
#  'Restaurants': 3,
#  'Movies & DVDs': 4,
#  'Home Improvement': 5,
#  'Utilities': 6,
#  'Music': 7,
#  'Mobile Phone': 8,
#  'Gas & Fuel': 9,
#  'Groceries': 10,
#  'Fast Food': 11,
#  'Coffee Shops': 12,
#  'Internet': 13,
#  'Haircut': 14,
#  'Alcohol & Bars': 15,
#  'Auto Insurance': 16,
#  'Entertainment': 17,
#  'Food & Dining': 18,
#  'Television': 19,
#  'Electronics & Software': 20}

# %%
income_id = {
    'Salary': 101,
    'Mutual Funds': 102,
    'Stocks': 103
}
income_id
# Out:
# {'Salary': 101, 'Mutual Funds': 102, 'Stocks': 103}

# %%
ids = {}
ids.update(expense_id)
ids.update(income_id)
ids
# Out:
# {'Shopping': 1,
#  'Mortgage & Rent': 2,
#  'Restaurants': 3,
#  'Movies & DVDs': 4,
#  'Home Improvement': 5,
#  'Utilities': 6,
#  'Music': 7,
#  'Mobile Phone': 8,
#  'Gas & Fuel': 9,
#  'Groceries': 10,
#  'Fast Food': 11,
#  'Coffee Shops': 12,
#  'Internet': 13,
#  'Haircut': 14,
#  'Alcohol & Bars': 15,
#  'Auto Insurance': 16,
#  'Entertainment': 17,
#  'Food & Dining': 18,
#  'Television': 19,
#  'Electronics & Software': 20,
#  'Salary': 101,
#  'Mutual Funds': 102,
#  'Stocks': 103}

# %% [markdown]
# ## replacing category with category_ids

# %%
df = df
df = df.replace({"Category":ids})
df
# Out:
#     transaction_id       Date sender_id receiver_id   Amount Transaction Type  \
# 0         37bfb35c 2021-05-20    abc123   e8e8-44bc    11.11          expense
# 1         04d83407 2021-05-21    abc123   f8e8-4956  1247.44          expense
# 2         fda5e368 2021-05-21    abc123   03c7-48d2    24.22          expense
# 3         dfa69094 2021-05-22    abc123   5c10-40fd  2298.09           income
# 4         a381db26 2021-05-23    abc123   0538-4712    11.76          expense
# ..             ...        ...       ...         ...      ...              ...
# 801       e58ffd24 2023-02-13    abc123   dcf6-42dc  2250.00           income
# 802       5d0a55ab 2023-02-14    abc123   ebbc-411a    33.46          expense
# 803       649773cb 2023-02-14    abc123   e4a9-436c     4.27          expense
# 804       5afbbc78 2023-02-16    abc123   50f7-47ea     1.75          expense
# 805       15978ee0 2023-02-16    abc123   73b8-4f97    75.00          expense
#
#      Category
# 0           1
# ...

# %% [markdown]
# # Database data

# %% [markdown]
# ## category

# %%
ids
# Out:
# {'Shopping': 1,
#  'Mortgage & Rent': 2,
#  'Restaurants': 3,
#  'Movies & DVDs': 4,
#  'Home Improvement': 5,
#  'Utilities': 6,
#  'Music': 7,
#  'Mobile Phone': 8,
#  'Gas & Fuel': 9,
#  'Groceries': 10,
#  'Fast Food': 11,
#  'Coffee Shops': 12,
#  'Internet': 13,
#  'Haircut': 14,
#  'Alcohol & Bars': 15,
#  'Auto Insurance': 16,
#  'Entertainment': 17,
#  'Food & Dining': 18,
#  'Television': 19,
#  'Electronics & Software': 20,
#  'Salary': 101,
#  'Mutual Funds': 102,
#  'Stocks': 103}

# %%
cat = pd.DataFrame(list(ids.items()),columns = ['category_name','category_id'])

print (cat)
print (type(cat))
# Out:
#              category_name  category_id
# 0                 Shopping            1
# 1          Mortgage & Rent            2
# 2              Restaurants            3
# 3            Movies & DVDs            4
# 4         Home Improvement            5
# 5                Utilities            6
# 6                    Music            7
# 7             Mobile Phone            8
# 8               Gas & Fuel            9
# 9                Groceries           10
# 10               Fast Food           11
# 11            Coffee Shops           12
# 12                Internet           13
# 13                 Haircut           14
# 14          Alcohol & Bars           15
# 15          Auto Insurance           16
# 16           Entertainment           17
# 17           Food & Dining           18
# 18              Television           19
# 19  Electronics & Software           20
# 20                  Salary          101
# 21            Mutual Funds          102
# ...

# %%
cat = cat.iloc[:, [1, 0]]
cat
# Out:
#     category_id           category_name
# 0             1                Shopping
# 1             2         Mortgage & Rent
# 2             3             Restaurants
# 3             4           Movies & DVDs
# 4             5        Home Improvement
# 5             6               Utilities
# 6             7                   Music
# 7             8            Mobile Phone
# 8             9              Gas & Fuel
# 9            10               Groceries
# 10           11               Fast Food
# 11           12            Coffee Shops
# 12           13                Internet
# 13           14                 Haircut
# 14           15          Alcohol & Bars
# 15           16          Auto Insurance
# 16           17           Entertainment
# 17           18           Food & Dining
# 18           19              Television
# 19           20  Electronics & Software
# 20          101                  Salary
# 21          102            Mutual Funds
# ...

# %%
cat.insert(2, 'type', np.NaN)

cat['type'][cat['category_id']<=20] = 'expense'
cat['type'][cat['category_id']>20] = 'income'

cat
# Out:
#     category_id           category_name     type
# 0             1                Shopping  expense
# 1             2         Mortgage & Rent  expense
# 2             3             Restaurants  expense
# 3             4           Movies & DVDs  expense
# 4             5        Home Improvement  expense
# 5             6               Utilities  expense
# 6             7                   Music  expense
# 7             8            Mobile Phone  expense
# 8             9              Gas & Fuel  expense
# 9            10               Groceries  expense
# 10           11               Fast Food  expense
# 11           12            Coffee Shops  expense
# 12           13                Internet  expense
# 13           14                 Haircut  expense
# 14           15          Alcohol & Bars  expense
# 15           16          Auto Insurance  expense
# 16           17           Entertainment  expense
# 17           18           Food & Dining  expense
# ...

# %%
cat.to_csv('database/category.csv', index=False)

# %% [markdown]
# ## record

# %%
df
# Out:
#     transaction_id       Date sender_id receiver_id   Amount Transaction Type  \
# 0         37bfb35c 2021-05-20    abc123   e8e8-44bc    11.11          expense
# 1         04d83407 2021-05-21    abc123   f8e8-4956  1247.44          expense
# 2         fda5e368 2021-05-21    abc123   03c7-48d2    24.22          expense
# 3         dfa69094 2021-05-22    abc123   5c10-40fd  2298.09           income
# 4         a381db26 2021-05-23    abc123   0538-4712    11.76          expense
# ..             ...        ...       ...         ...      ...              ...
# 801       e58ffd24 2023-02-13    abc123   dcf6-42dc  2250.00           income
# 802       5d0a55ab 2023-02-14    abc123   ebbc-411a    33.46          expense
# 803       649773cb 2023-02-14    abc123   e4a9-436c     4.27          expense
# 804       5afbbc78 2023-02-16    abc123   50f7-47ea     1.75          expense
# 805       15978ee0 2023-02-16    abc123   73b8-4f97    75.00          expense
#
#      Category
# 0           1
# ...

# %%
df.drop('Transaction Type', axis=1, inplace=True)
df
# Out:
#     transaction_id       Date sender_id receiver_id   Amount  Category
# 0         37bfb35c 2021-05-20    abc123   e8e8-44bc    11.11         1
# 1         04d83407 2021-05-21    abc123   f8e8-4956  1247.44         2
# 2         fda5e368 2021-05-21    abc123   03c7-48d2    24.22         3
# 3         dfa69094 2021-05-22    abc123   5c10-40fd  2298.09       103
# 4         a381db26 2021-05-23    abc123   0538-4712    11.76         4
# ..             ...        ...       ...         ...      ...       ...
# 801       e58ffd24 2023-02-13    abc123   dcf6-42dc  2250.00       101
# 802       5d0a55ab 2023-02-14    abc123   ebbc-411a    33.46         9
# 803       649773cb 2023-02-14    abc123   e4a9-436c     4.27         9
# 804       5afbbc78 2023-02-16    abc123   50f7-47ea     1.75        12
# 805       15978ee0 2023-02-16    abc123   73b8-4f97    75.00        13
#
# [784 rows x 6 columns]

# %%
df.columns = ['transaction_id', 'trans_date', 'sender_id', 'receiver_id', 'amount', 'cat_id']
df
# Out:
#     transaction_id trans_date sender_id receiver_id   amount  cat_id
# 0         37bfb35c 2021-05-20    abc123   e8e8-44bc    11.11       1
# 1         04d83407 2021-05-21    abc123   f8e8-4956  1247.44       2
# 2         fda5e368 2021-05-21    abc123   03c7-48d2    24.22       3
# 3         dfa69094 2021-05-22    abc123   5c10-40fd  2298.09     103
# 4         a381db26 2021-05-23    abc123   0538-4712    11.76       4
# ..             ...        ...       ...         ...      ...     ...
# 801       e58ffd24 2023-02-13    abc123   dcf6-42dc  2250.00     101
# 802       5d0a55ab 2023-02-14    abc123   ebbc-411a    33.46       9
# 803       649773cb 2023-02-14    abc123   e4a9-436c     4.27       9
# 804       5afbbc78 2023-02-16    abc123   50f7-47ea     1.75      12
# 805       15978ee0 2023-02-16    abc123   73b8-4f97    75.00      13
#
# [784 rows x 6 columns]

# %%
df['amount'] = df['amount'].astype(int)
df
# Out:
#     transaction_id trans_date sender_id receiver_id  amount  cat_id
# 0         37bfb35c 2021-05-20    abc123   e8e8-44bc      11       1
# 1         04d83407 2021-05-21    abc123   f8e8-4956    1247       2
# 2         fda5e368 2021-05-21    abc123   03c7-48d2      24       3
# 3         dfa69094 2021-05-22    abc123   5c10-40fd    2298     103
# 4         a381db26 2021-05-23    abc123   0538-4712      11       4
# ..             ...        ...       ...         ...     ...     ...
# 801       e58ffd24 2023-02-13    abc123   dcf6-42dc    2250     101
# 802       5d0a55ab 2023-02-14    abc123   ebbc-411a      33       9
# 803       649773cb 2023-02-14    abc123   e4a9-436c       4       9
# 804       5afbbc78 2023-02-16    abc123   50f7-47ea       1      12
# 805       15978ee0 2023-02-16    abc123   73b8-4f97      75      13
#
# [784 rows x 6 columns]

# %%
df.loc[df['cat_id'] <= 20]['amount'].sum()
# Out:
# 58758

# %%
df.to_csv('database/record.csv', index=False)
