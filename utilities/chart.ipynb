# %%
import plotly.graph_objects as go

import plotly.express as px

# Use included Google price data to make one plot
df_stocks = px.data.stocks()
px.line(df_stocks, x='date', y='GOOG', labels={'x':'Date', 'y':'Price'})

# %%
df_stocks
# Out:
#            date      GOOG      AAPL      AMZN        FB      NFLX      MSFT
# 0    2018-01-01  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1    2018-01-08  1.018172  1.011943  1.061881  0.959968  1.053526  1.015988
# 2    2018-01-15  1.032008  1.019771  1.053240  0.970243  1.049860  1.020524
# 3    2018-01-22  1.066783  0.980057  1.140676  1.016858  1.307681  1.066561
# 4    2018-01-29  1.008773  0.917143  1.163374  1.018357  1.273537  1.040708
# ..          ...       ...       ...       ...       ...       ...       ...
# 100  2019-12-02  1.216280  1.546914  1.425061  1.075997  1.463641  1.720717
# 101  2019-12-09  1.222821  1.572286  1.432660  1.038855  1.421496  1.752239
# 102  2019-12-16  1.224418  1.596800  1.453455  1.104094  1.604362  1.784896
# 103  2019-12-23  1.226504  1.656000  1.521226  1.113728  1.567170  1.802472
# 104  2019-12-30  1.213014  1.678000  1.503360  1.098475  1.540883  1.788185
#
# [105 rows x 7 columns]

# %%
import pandas as pd

df = pd.read_csv('database/record.csv')
px.line(df, x='trans_date', y='amount', labels={'x':'Date', 'y':'Price'})

# %%
df = df.assign(sum=df['amount'].cumsum())
px.line(df, x='trans_date', y='sum', labels={'x':'Date', 'y':'Price'})

# %%
inc = df.loc[df['cat_id'] >= 100]
inc
# Out:
#     transaction_id  trans_date sender_id receiver_id  amount  cat_id     sum
# 3         dfa69094  2021-05-22    abc123   5c10-40fd    2298     103    3580
# 13        ef832a90  2021-05-31    abc123   def8-4d8b    2000     101    5870
# 20        e339fd72  2021-06-07    abc123   3f68-4ca4    2000     101    8144
# 22        97e27457  2021-06-10    abc123   1bd9-488b     554     103    8748
# 23        9767e2cd  2021-06-10    abc123   f8d4-4640     309     102    9057
# ..             ...         ...       ...         ...     ...     ...     ...
# 763       243e2a8c  2023-01-30    abc123   804f-43fb    2250     101  179760
# 767       ce4d1883  2023-02-02    abc123   acd7-487a      90     102  180033
# 769       0db653b6  2023-02-03    abc123   f770-4b17     186     103  180254
# 774       abd0c3c3  2023-02-06    abc123   2283-4785       9     103  180440
# 779       e58ffd24  2023-02-13    abc123   dcf6-42dc    2250     101  182881
#
# [118 rows x 7 columns]

# %%
inc = inc.assign(sum=df['amount'].cumsum())
px.line(df, x='trans_date', y='sum', labels={'x':'Date', 'y':'Price'})
