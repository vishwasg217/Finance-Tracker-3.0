# %%
import pandas as pd
import numpy as np
import seaborn as sns
print('hello')
# Out:
# hello

# %%
df = pd.read_csv('eda.csv')
df.head()
# Out:
#   transaction_id        Date  sender_id receiver_id  Amount Transaction Type  \
# 0       d3b83e4f  2021-08-14     abc123   313c-45c1  960.92          expense
# 1       63770774  2021-08-14     abc123   2a6f-47f5    1.75          expense
# 2       2646d40f  2021-08-14  d329-42d5      abc123    1.75           income
# 3       4920a68a  2021-08-14     abc123   f4dd-4310    1.75          expense
# 4       67c891cd  2021-08-14  e98a-4853      abc123  626.54           income
#
#          Category
# 0        Internet
# 1     Restaurants
# 2     Restaurants
# 3  Alcohol & Bars
# 4        Paycheck

# %%
df.describe()
# Out:
#             Amount
# count  5000.000000
# mean    455.423990
# std     854.147438
# min       1.750000
# 25%       1.750000
# 50%     149.340000
# 75%     199.080000
# max    3363.830000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_id    5000 non-null   object
#  1   Date              5000 non-null   object
#  2   sender_id         5000 non-null   object
#  3   receiver_id       5000 non-null   object
#  4   Amount            5000 non-null   float64
#  5   Transaction Type  5000 non-null   object
#  6   Category          5000 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 273.6+ KB

# %%
sns.pairplot(df)

# %%
cat_cols = df.select_dtypes(include='object').columns

sns.barplot(data=df,x='Amount', y='Category')
# Out:
# <AxesSubplot: xlabel='Amount', ylabel='Category'>

# %%
df['Category'].unique()
# Out:
# array(['Internet', 'Restaurants', 'Alcohol & Bars', 'Paycheck',
#        'Mortgage & Rent', 'Haircut', 'Stocks', 'Auto Insurance',
#        'Fast Food', 'Coffee Shops', 'Utilities', 'Mutual Funds',
#        'Groceries', 'Home Improvement', 'Shopping', 'Gas & Fuel', 'Music',
#        'Movies & DVDs', 'Food & Dining', 'Mobile Phone',
#        'Electronics & Software', 'Television', 'Entertainment'],
#       dtype=object)

# %%
income = ['Paycheck', 'Stocks', 'Mutual Funds']
restaurant = ['Restaurants', 'Alcohol & Bars', 'Fast Food', 'Coffee Shops', 'Food & Dining']
movies_and_tv = ['Movies & DVDs', 'Television']
utilities = ['Utilities', 'Haircut']
travel = ['Gas & Fuel', 'Auto Insurance']
entertainment
electronics
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 6
#       4 utilities = ['Utilities', 'Haircut']
#       5 travel = ['Gas & Fuel', 'Auto Insurance']
# ----> 6 entertainment
#       7 electronics
#
# NameError: name 'entertainment' is not defined
